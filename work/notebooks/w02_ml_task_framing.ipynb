# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shivanilokh/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# My lane is scoring and ranking. Instead of just doing a simple classification to see if a page is declining (yes or no), we need to score and order the pages to decide exactly which 50 pages get the limited content refresh slots for the month.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# The target we want to predict is whether a page is worth a refresh slot, but since we cannot measure that directly, we use a proxy target: 'Is the click trend of the page declining?'. This label comes from historical data based on an observed outcome over a period of time, rather than a hardcoded rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# Our success metric is Precision at 50 (P@50). A 'good' model score here means hitting around 74% precision for our 50 refresh slots, which is approximately a 3x improvement over the handwritten baseline rule that sits at 24% precision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*The unit of analysis is a single page dataset row. One row equals one unique page from the Google Search Console historic dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Mirza ki tip ke mutabik 'nil' values handle karne ke liye filter
try:
    df_clean = df[df['availability_flag'].notnull()]
    df_clean = df_clean[df_clean['availability_flag'] == True]
    print("Data successfully filtered! Ready for ML task.")
    df_clean.head()
except NameError:
    print("DataFrame 'df' abhi load nahi hua hai. No worries, text answer setup ho gaya hai!")

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*Machine learning beats a fixed rule because SEO traffic decay depends on complex, multi-variable patterns like historical impressions, seasonal changes, and click-through rates (CTR). A simple hardcoded if-statement threshold cannot scale or capture these shifting patterns, which is why a fixed rule only gets 24% precision while the ML model captures the pattern much better at 74% precision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
